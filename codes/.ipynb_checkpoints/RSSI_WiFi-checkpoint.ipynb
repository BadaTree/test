# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import copy
import time
import os

# %%
class wifimodel():
    def __init__(self, location):
        self.train_dir = f'../data/{location}/train/'
        self.test_dir = f'../data/{location}/test_01_26/'
        
        self.location = location
        self.model_df = pd.DataFrame()
        self.test_df = pd.DataFrame()

        self.fil_model_df = pd.DataFrame()
        self.fil_test_df = pd.DataFrame()

        self.SSID_list = []
        
        self.test_x_list = []
        self.test_y_list = []
        
        self.maxarea = 0
        self.maxarea2 = 0
        self.refwifi = []

        self.rssi_thres = 0
        self.range_num = 0
        self.range_num2 = 0

        file_list = os.listdir(self.train_dir)
        for file in file_list:
            df = pd.read_csv(self.train_dir + file,
                             sep="\t", engine='python', encoding="UTF-8", header=None)
            df = pd.DataFrame(
                {"cnt": list(df.iloc[:, 0]), "x": list(df.iloc[:, 1]), "y": list(df.iloc[:, 2]),
                 "ADDR": list(df.iloc[:, 3]),
                 "SSID": list(df.iloc[:, 4]),
                 "RSSI": list(df.iloc[:, 5])})
            self.model_df = pd.concat([self.model_df, df])

        file_list = os.listdir(self.test_dir)
        for file in file_list:
            df = pd.read_csv(self.test_dir + file,
                             sep="\t", engine='python', encoding="UTF-8", header=None)
            df = pd.DataFrame(
                {"cnt": list(df.iloc[:, 0]), "x": list(df.iloc[:, 1]), "y": list(df.iloc[:, 2]),
                 "ADDR": list(df.iloc[:, 3]),
                 "SSID": list(df.iloc[:, 4]),
                 "RSSI": list(df.iloc[:, 5])})
            self.test_df = pd.concat([self.test_df, df])
        
        self.mag_df = pd.read_csv(f'../mag/{location}/magx.txt', sep="\t", engine='python', encoding="cp949", header=None)

        self.ref_mag_df = copy.deepcopy(self.mag_df)
        
        for i in range(self.mag_df.shape[0]):
            for j in range(self.mag_df.shape[1]):
                if ((i % 6 == 0 ) and (j % 6 == 0) and (self.mag_df.iloc[i, j] != 0.0)):
                    self.maxarea += 1
        
        self.maxarea2 = sum(self.ref_mag_df[self.ref_mag_df != 0.0].count())
        self.mag_df[self.mag_df != 0.0] = np.nan

        self.maxX = self.mag_df.shape[0]
        self.maxY = self.mag_df.shape[1]

    def cal_area(self, posx, posy):
        cnt = 0
        temp = self.ref_mag_df.iloc[int(min(posx)): int(max(posx)), int(min(posy)): int(max(posy))]
        return sum(temp[temp != 0.0].count())
    
    def cal_area2(self, posx, posy):
        cnt = 0
        for i in range(len(posx)):
            if self.mag_df.iloc[posx[i], posy[i]] != 0.0:
                cnt += 1
        return cnt
    
    def define_range(self, range_num, rssi_range_num):
        self.range_num = range_num
        self.rssi_range_num = rssi_range_num
        
    def create_refwifi(self, rssi_thres):
        self.rssi_thres = rssi_thres
        
        fil_model_df = self.model_df.loc[self.model_df['RSSI'] >= self.rssi_thres]
        self.fil_test_df = self.test_df.loc[self.test_df['RSSI'] >= self.rssi_thres]

        self.SSID_list = list(fil_model_df['SSID'].unique())
        self.test_x_list = self.fil_test_df['x'].unique()
        self.test_y_list = self.fil_test_df['y'].unique()
        
        self.refwifi = np.zeros((self.maxX, self.maxY, len(self.SSID_list)), dtype = np.int64)
        self.rssiwifi = np.zeros((self.maxX, self.maxY, len(self.SSID_list)), dtype = np.int64)
        
        self.rssi_max = np.max(fil_model_df['RSSI'])
        for i in range(fil_model_df.shape[0]):
            posx = fil_model_df.iloc[i, 1]
            posy = fil_model_df.iloc[i, 2]
            ssid = fil_model_df.iloc[i, 4]
            rssi = fil_model_df.iloc[i, 5]
            if(0 <= posx < self.maxX) and (0 <= posy < self.maxY):
                self.refwifi[int(posx)][int(posy)][self.SSID_list.index(ssid)] = 1
                self.rssiwifi[int(posx)][int(posy)][self.SSID_list.index(ssid)] = rssi

    def test_all(self):
        tot_cnt = 0
        cnt = 0
        self.area_list = []
        coords_list = []
        fail_list = []
        

        for x in self.test_x_list:
            for y in self.test_y_list:
                compare_list = np.array([0 for i in range(len(self.SSID_list))])
                compare_list_rssi = np.array([0 for i in range(len(self.SSID_list))])

                compare_df = self.fil_test_df.loc[(self.fil_test_df["x"] == x) & (self.fil_test_df["y"] == y)]
                if compare_df.empty == False:
                    for i in range(compare_df.shape[0]):
                        if (compare_df.iloc[i, 4] in self.SSID_list):
                            compare_list[self.SSID_list.index(compare_df.iloc[i, 4])] = -1
                            compare_list_rssi[self.SSID_list.index(compare_df.iloc[i, 4])] = compare_df.iloc[i, 5]

                    temp_wifi = self.refwifi - compare_list
                    temp_wifi = np.where(temp_wifi == 1, 0, temp_wifi)

                    temp_rssi_wifi = abs(self.rssiwifi - compare_list_rssi)
                    temp_rssi_wifi = np.where(abs(temp_rssi_wifi) >= abs(self.rssi_max), 0, temp_rssi_wifi)

                    sum_temp = temp_wifi.sum(axis=2)

                    sum_temp_for_rssi = copy.deepcopy(sum_temp)

                    sum_temp_for_rssi = np.where(sum_temp_for_rssi == 0, 0.00001, sum_temp)
                    sum_rssi_temp = temp_rssi_wifi.sum(axis=2)

                    sum_rssi_temp = sum_rssi_temp / sum_temp_for_rssi

                    sum_np = np.unique(sum_temp.flatten())[:: -1]

                    if len(sum_np) <= self.range_num:
                        range_idx = len(sum_np) - 1
                    else:
                        range_idx = self.range_num

                    if range_idx == -1:
                        rangeval = 0
                    else:
                        rangeval = np.unique(sum_np)[:: - 1][range_idx]

                    sum_rssi_np = np.unique(sum_rssi_temp[np.where(sum_temp >= rangeval)].flatten())

                    if len(sum_rssi_np) <= self.rssi_range_num:
                        range_idx = len(sum_rssi_np) - 1
                    else:
                        range_idx = self.rssi_range_num

                    if range_idx == -1:
                        rssi_rangeval = 0
                    else:
                        rssi_rangeval = np.unique(sum_rssi_np)[range_idx]

                    coords = np.where((sum_temp >= rangeval) & (sum_rssi_temp <= rssi_rangeval))

                    if (min(coords[0]) <= x <= max(coords[0]) and min(coords[1]) <= y <= max(coords[1])):
                        cnt += 1
                        coords_list.append([x, y, coords])
                        self.area_list.append((max(coords[0]) - min(coords[0])) * (max(coords[1]) - min(coords[1]))
                                              / (self.maxX * self.maxY))
                    else:
                        fail_list.append([x, y, coords])
                    tot_cnt += 1
                    
                    if (tot_cnt % 100 == 0):
                        print(f"현재 진행 상황 : {tot_cnt} 회")
                        print(f"성공 횟수 : {cnt}회")
        
        
        print(f"test 횟수 : {tot_cnt}, 성공 횟수 : {cnt}")
        print(cnt * 100 / tot_cnt)
        print(np.average(self.area_list))
        
        return coords_list, cnt / tot_cnt, np.average(self.area_list), fail_list
    
    def show_area_dist(self):
        plt.hist(pd.DataFrame(self.area_list).values)
        plt.show()
    
    def test_one(self, idx):
        tot_cnt = 0
        cnt = 0
        self.area_list = []
        coords_list = []
        
        self.fil_test_df['x_y'] = self.fil_test_df['x'].astype('str') + "\t" + self.fil_test_df['y'].astype('str')
        test_list = list(self.fil_test_df['x_y'].unique())[idx].split('\t')
        
        x = float(test_list[0])
        y = float(test_list[1])
        
        compare_list = np.array([0 for i in range(len(self.SSID_list))])
        compare_list_rssi = np.array([0 for i in range(len(self.SSID_list))])
        
        compare_df = self.fil_test_df.loc[(self.fil_test_df["x"] == x) & (self.fil_test_df["y"] == y)]
        
        
        if compare_df.empty == False:
            for i in range(compare_df.shape[0]):
                if (compare_df.iloc[i, 4] in self.SSID_list):
                    compare_list[self.SSID_list.index(compare_df.iloc[i, 4])] = -1
                    compare_list_rssi[self.SSID_list.index(compare_df.iloc[i, 4])] = compare_df.iloc[i, 5]
                    
            temp_wifi = self.refwifi - compare_list
            temp_wifi = np.where(temp_wifi == 1, 0, temp_wifi)
            
            temp_rssi_wifi = abs(self.rssiwifi - compare_list_rssi)
            temp_rssi_wifi = np.where(abs(temp_rssi_wifi) >= abs(self.rssi_max), 0, temp_rssi_wifi)
            
            sum_temp = temp_wifi.sum(axis=2)
            
            sum_temp_for_rssi = copy.deepcopy(sum_temp)
            
            sum_temp_for_rssi = np.where(sum_temp_for_rssi == 0, 0.00001, sum_temp)
            sum_rssi_temp = temp_rssi_wifi.sum(axis=2)
            
            sum_rssi_temp = sum_rssi_temp / sum_temp_for_rssi
            
            sum_np = np.unique(sum_temp.flatten())[:: -1]
            
            if len(sum_np) <= self.range_num:
                range_idx = len(sum_np) - 1
            else:
                range_idx = self.range_num

            if range_idx == -1:
                rangeval = 0
            else:
                rangeval = np.unique(sum_np)[:: - 1][range_idx]
            
            sum_rssi_np = np.unique(sum_rssi_temp[np.where(sum_temp >= rangeval)].flatten())
            
            if len(sum_rssi_np) <= self.rssi_range_num:
                range_idx = len(sum_rssi_np) - 1
            else:
                range_idx = self.rssi_range_num
            
            if range_idx == -1:
                rssi_rangeval = 0
            else:
                rssi_rangeval = np.unique(sum_rssi_np)[range_idx]
                        
            coords = np.where((sum_temp >= rangeval) & (sum_rssi_temp <= rssi_rangeval))
                                                                          
            coords_list.append([x, y, coords])
            self.area_list.append((max(coords[0]) - min(coords[0])) * (max(coords[1]) - min(coords[1]))
                      / (self.maxX * self.maxY))
        
        return coords_list, x, y,coords, sum_np
    
    def save_refwifi(self):
        file_name = f'../wifihashmap/{self.location}/{self.location}_wifihashmap.txt'

        path_save = open(file_name, 'w')

        for x in range(self.maxX + 1):
            for y in range(self.maxY + 1):
                if(x % 6 == 0) and (y % 6 == 0):
                    content = str(x) + "\t" + str(y) + "\t" + "".join(list(map(str, self.refwifi[x][y]))) + "\n"
                    path_save.write(content)
        path_save.close()
        
        file_name = f'../wifihashmap/{self.location}/{self.location}_wifilist.txt'

        path_save = open(file_name, 'w')

        content = "\t".join(self.SSID_list)
        path_save.write(content)
        path_save.close()
    
    def save_rssiwifi(self):
        file_name = f'../wifihashmap/{self.location}/{self.location}_wifirssihashmap.txt'

        path_save = open(file_name, 'w')

        for x in range(self.maxX + 1):
            for y in range(self.maxY + 1):
                if(x % 6 == 0) and (y % 6 == 0):
                    content = str(x) + "\t" + str(y) + "\t" + " ".join(list(map(str, self.rssiwifi[x][y]))) + "\n"
                    path_save.write(content)
        path_save.close()

# %%
thres_list = [-75]
range_val = [7]
rssi_range = [34]

area_thres1 = 0.0
area_thres2 = 1.0

test_slicer = 1

model = wifimodel('하나스퀘어')
model.create_refwifi(thres_list[0])
model.define_range(range_val[0], rssi_range[0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-362a7e079462> in <module>
#       8 test_slicer = 1
#       9
# ---> 10 model = wifimodel('하나스퀘어')
#      11 model.create_refwifi(thres_list[0])
#      12 model.define_range(range_val[0], rssi_range[0])
#
# NameError: name 'wifimodel' is not defined

# %%
# model.save_refwifi()
# model.save_rssiwifi()

# %%
tot_acc_list = []
tot_list_area = []

tot_area_dist = []
for thres in thres_list:
    model.create_refwifi(thres)
    acc_list = []
    list_area = []
    area_dist = []
#     for rang in range_val:
    for range_for_rssi in rssi_range:
        model.define_range(range_val[0], range_for_rssi)
        cord, acc, ara, fail = model.test_all()
        acc_list.append(acc)
        list_area.append(ara)
        area_dist.append(model.area_list)
    tot_acc_list.append(acc_list)
    tot_list_area.append(list_area)
    tot_area_dist.append(area_dist)
# Out:
# 현재 진행 상황 : 100 회
# 성공 횟수 : 86회
# 현재 진행 상황 : 200 회
# 성공 횟수 : 181회
# 현재 진행 상황 : 300 회
# 성공 횟수 : 275회
# 현재 진행 상황 : 400 회
# 성공 횟수 : 355회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 435회
# 현재 진행 상황 : 600 회
# 성공 횟수 : 511회
# 현재 진행 상황 : 700 회
# 성공 횟수 : 570회
# 현재 진행 상황 : 800 회
# 성공 횟수 : 670회
# 현재 진행 상황 : 900 회
# 성공 횟수 : 739회
# test 횟수 : 951, 성공 횟수 : 774
# 81.38801261829653
# 0.1983700109278015

# %%
for i in range(100, 177):
    x_list = fail[i][2][0]
    y_list = fail[i][2][1]
    
    ans_x = fail[i][0]
    ans_y = fail[i][1]
    
    print(min(x_list), max(x_list), min(y_list), max(y_list))

    # org_x_list = orig_coord[0]
    # org_y_list = orig_coord[1]

    print(ans_x, ans_y)
    
#     flt_x, flt_y = make_range2(x_list, y_list)

    # plt.figure(figsize = (15, 11))
    # plt.imshow(mag_df, cmap='jet', interpolation='none')
    # plt.scatter(org_y_list, org_x_list, c = 'b')
    # plt.scatter(y, x, c = 'r')


    plt.figure(figsize = (15, 11))
    plt.imshow(model.mag_df, cmap='jet', interpolation='none')
    plt.scatter(y_list, x_list, c = 'r')
    plt.scatter(ans_y, ans_x, c = 'black')

    plt.show()
    
#     plt.figure(figsize = (15, 11))
#     plt.imshow(model.mag_df, cmap='jet', interpolation='none')
#     plt.scatter(flt_y, flt_x, c = 'r')
#     plt.scatter(ans_y, ans_x, c = 'black')

#     plt.show()
# Out:
# 78 258 846 1098
# 279.03723805784483 888.6251459503239
# 78 258 846 1098
# 278.7219802401845 894.6406234609757
# 78 258 846 1098
# 278.93287828960985 900.6799534211923
# 78 258 846 1098
# 278.4077295501684 906.6824309797374
# 78 258 810 1098
# 278.3021498443188 912.7310882768443
# 78 258 810 1098
# 277.77446764688585 918.7625233927396
# 78 258 810 1098
# 277.77446764688585 924.8343818951196
# 78 258 810 1098
# 277.3476243608705 930.9385252723433
# 78 258 936 1170
# 277.56200208355864 937.0775000374555
# 78 258 936 1170
# 277.45460532776804 943.2302560559668
# 78 258 936 1170
# 277.99191140978485 949.3716926760104
# 78 258 936 1170
# 277.7756241475271 955.565349499892
# 78 258 936 1170
# 278.41834621245465 961.6804414683832
# 78 258 936 1170
# 278.52552699315015 967.8208242819832
# 78 252 924 1176
# 278.8454610196475 973.9255291726342
# 78 252 924 1176
# 278.8454610196475 980.0172611032452
# 78 252 924 1176
# 279.26821390235 986.0629089878363
# 78 252 924 1176
# 279.0579670060581 992.0835923619984
# 78 252 924 1176
# 279.2670869542024 998.0720041635666
# 78 258 918 1116
# 278.7479061445174 1004.0062679728552
# 78 258 918 1116
# 278.7479061445174 1009.9635265834088
# 78 258 918 1116
# 277.81840847373104 1015.8321439102227
# 78 258 918 1116
# 276.47189146677005 1021.6645498401876
# 78 258 918 1116
# 273.47754418454923 1026.8509114685
# 84 252 960 1146
# 269.554041138372 1031.3643854184577
# 84 252 960 1146
# 264.46088159537135 1034.5469447212633
# 84 252 960 1146
# 259.1731011022056 1037.4780093107206
# 84 252 960 1146
# 253.3940839323534 1039.244832168221
# 102 258 1038 1104
# 180.0803638700599 1035.9093602264468
# 102 258 1038 1104
# 174.3631065918649 1033.1208675346554
# 0 222 384 732
# -0.19517070434660688 467.7096609048429
# 0 222 384 732
# -0.6229488322678525 461.5921486655202
# 0 222 384 732
# -1.047346565099644 455.52297832818743
# 0 258 0 750
# -1.3637281149877658 449.4860587292969
# 0 258 0 750
# -1.7823403159495714 443.49962535235437
# 0 258 0 750
# -1.9894026849828867 437.57013490735596
# 0 258 0 750
# -2.503454785638215 431.6944925105211
# 0 258 0 750
# -2.9145723607359098 425.8152372767802
# 0 258 0 750
# -3.4294103440738097 419.93061219977983
# 0 222 24 636
# -3.838001221725037 414.08749042295256
# 0 222 24 636
# -4.345730657978728 408.28411641092123
# 0 222 24 636
# -4.548311913706906 402.4829482615182
# 0 222 24 636
# -4.956432356734801 396.6465540132348
# 0 222 24 636
# -5.1606609494482125 390.7982123046801
# 0 222 24 636
# -5.468510452571598 384.9240938563336
# 0 222 0 576
# -5.77981269579313 378.9840932022271
# 0 222 0 576
# -6.301634595930778 373.01964159092745
# 0 222 0 576
# -6.406737929388986 366.9982756498417
# 0 222 0 576
# -6.82875529174389 360.9631461962664
# 0 222 0 576
# -6.828755291743889 354.8515286756602
# 0 222 0 516
# -7.14911335936411 348.73873259838217
# 0 222 0 516
# -6.932830453689934 342.5452005307316
# 0 222 0 516
# -6.606180288851313 336.312344086377
# 0 222 0 516
# -4.776941301275484 330.3291729540313
# 0 222 0 516
# -1.3718923314561629 325.08585734533364
# 0 222 0 300
# 99.26242853559644 314.3386203557495
# 0 222 0 300
# 105.41241466376322 314.23127194857466
# 0 222 0 300
# 111.55884084492395 314.5533924952565
# 0 222 0 300
# 117.73067566303615 314.5533924952565
# 0 222 0 300
# 123.94797746333929 314.8792274757428
# 0 222 0 300
# 130.15554924625903 314.98758104426025
# 0 186 30 276
# 32.01798148410737 277.6856010891807
# 0 186 30 276
# 33.59609356787167 284.01506294572505
# 6 222 6 294
# 38.82883371546072 295.7814605001432
# 6 222 6 294
# 43.0839811945792 300.5072805428961
# 6 222 6 294
# 48.5088646490389 303.63933846565084
# 6 222 6 294
# 54.269150597211116 305.85050507267397
# 12 222 0 300
# 60.23434877066119 307.22767958468387
# 12 222 0 300
# 66.28985023124315 308.18677679440265
# 12 222 0 300
# 72.41918947435875 308.29376480885827
# 12 222 0 300
# 78.50461096441012 308.39998623608267
# 12 222 0 300
# 84.53225842866912 307.6598841889061
# 36 222 6 294
# 90.58749774125948 307.23646060822165
# 36 222 6 294
# 96.59274514095272 306.499108943137
# 36 222 6 294
# 102.62452989189389 306.07732546517417
# 36 222 6 294
# 108.60682786529628 305.4485606115484
# 36 222 6 294
# 114.57680861096745 305.34435421001245

# %%
for i in range(len(tot_acc_list)):
    print(thres_list[i])
    print(tot_acc_list[i])
    print(tot_list_area[i])
    plt.figure(figsize = (8, 4))
    plt.plot(rssi_range,tot_acc_list[i])
    plt.plot(rssi_range,tot_list_area[i])
    plt.scatter(rssi_range, tot_acc_list[i])
    plt.scatter(rssi_range, tot_list_area[i])
    plt.show()

# %%
plt.figure(figsize = (10, 7))
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.rc('axes', labelsize=20)
plt.xlabel('Area_Decrease_Rate')
plt.ylabel('Sample_Number')
plt.hist(model.area_list)
plt.show()

# %%
thres_list = [-64]
range_val = [4]
rssi_range = [32]

area_thres1 = 0.0
area_thres2 = 1.0


model = wifimodel('포스코센터')

# %%
tot_acc_list = []
tot_list_area = []

tot_area_dist = []
for thres in thres_list:
    model.create_refwifi(thres)
    acc_list = []
    list_area = []
    area_dist = []
#     for rang in range_val:
    for range_for_rssi in rssi_range:
        model.define_range(range_val[0], range_for_rssi)
        cord, acc, ara, fail = model.test_all()
        acc_list.append(acc)
        list_area.append(ara)
        area_dist.append(model.area_list)
    tot_acc_list.append(acc_list)
    tot_list_area.append(list_area)
    tot_area_dist.append(area_dist)
# Out:
# 현재 진행 상황 : 100 회
# 성공 횟수 : 100회
# 현재 진행 상황 : 200 회
# 성공 횟수 : 200회
# test 횟수 : 253, 성공 횟수 : 248
# 98.02371541501977
# 0.09973264411508471

# %%
plt.figure(figsize = (10, 7))
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.rc('axes', labelsize=20)
plt.xlabel('Area_Decrease_Rate')
plt.ylabel('Sample_Number')
plt.hist(model.area_list)
plt.show()

# %%
thres_list = [-78]
range_val = [2]
rssi_range = [20]

area_thres1 = 0.0
area_thres2 = 1.0

test_slicer = 1

model = wifimodel('포스코실험동')

# %%
tot_acc_list = []
tot_list_area = []

tot_area_dist = []
for thres in thres_list:
    model.create_refwifi(thres)
    acc_list = []
    list_area = []
    area_dist = []
#     for rang in range_val:
    for range_for_rssi in rssi_range:
        model.define_range(range_val[0], range_for_rssi)
        cord, acc, ara, fail = model.test_all()
        acc_list.append(acc)
        list_area.append(ara)
        area_dist.append(model.area_list)
    tot_acc_list.append(acc_list)
    tot_list_area.append(list_area)
    tot_area_dist.append(area_dist)
# Out:
# 현재 진행 상황 : 100 회
# 성공 횟수 : 94회
# 현재 진행 상황 : 200 회
# 성공 횟수 : 194회
# 현재 진행 상황 : 300 회
# 성공 횟수 : 294회
# 현재 진행 상황 : 400 회
# 성공 횟수 : 394회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 494회
# 현재 진행 상황 : 600 회
# 성공 횟수 : 594회
# test 횟수 : 655, 성공 횟수 : 630
# 96.18320610687023
# 0.29084162383811024

# %%
plt.figure(figsize = (10, 7))
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.rc('axes', labelsize=20)
plt.xlabel('Area_Decrease_Rate')
plt.ylabel('Sample_Number')
plt.hist(model.area_list)
plt.show()

# %%
thres_list = [-63]
range_val = [4]
rssi_range = [28, 30, 32, 34, 36, 38]

area_thres1 = 0.0
area_thres2 = 1.0

test_slicer = 1

model = wifimodel('포스코센터')

# %%
tot_acc_list = []
tot_list_area = []

tot_area_dist = []
for thres in thres_list:
    model.create_refwifi(thres)
    acc_list = []
    list_area = []
    area_dist = []
#     for rang in range_val:
    for range_for_rssi in rssi_range:
        model.define_range(range_val[0], range_for_rssi)
        cord, acc, ara, fail = model.test_all()
        acc_list.append(acc)
        list_area.append(ara)
        area_dist.append(model.area_list)
    tot_acc_list.append(acc_list)
    tot_list_area.append(list_area)
    tot_area_dist.append(area_dist)
# Out:
# 현재 진행 상황 : 100 회
# 성공 횟수 : 96회
# 현재 진행 상황 : 200 회
# 성공 횟수 : 191회
# test 횟수 : 253, 성공 횟수 : 241
# 95.25691699604744
# 0.08921592490041928
# 현재 진행 상황 : 100 회
# 성공 횟수 : 99회
# 현재 진행 상황 : 200 회
# 성공 횟수 : 194회
# test 횟수 : 253, 성공 횟수 : 246
# 97.23320158102767
# 0.09176570338332064
# 현재 진행 상황 : 100 회
# 성공 횟수 : 100회
# 현재 진행 상황 : 200 회
# 성공 횟수 : 199회
# test 횟수 : 253, 성공 횟수 : 252
# 99.60474308300395
# 0.09557980378599651
# 현재 진행 상황 : 100 회
# 성공 횟수 : 100회
# 현재 진행 상황 : 200 회
# 성공 횟수 : 199회
# test 횟수 : 253, 성공 횟수 : 252
# 99.60474308300395
# 0.09954171309025055
# 현재 진행 상황 : 100 회
# 성공 횟수 : 100회
# 현재 진행 상황 : 200 회
# 성공 횟수 : 200회
# test 횟수 : 253, 성공 횟수 : 253
# 100.0
# 0.10223385378375374
# 현재 진행 상황 : 100 회
# 성공 횟수 : 100회
# 현재 진행 상황 : 200 회
# 성공 횟수 : 200회
# test 횟수 : 253, 성공 횟수 : 253
# 100.0
# 0.10464540790690782

# %%
for i in range(len(tot_acc_list)):
    print(thres_list[i])
    print(tot_acc_list[i])
    print(tot_list_area[i])
    plt.figure(figsize = (8, 4))
    plt.plot(rssi_range,tot_acc_list[i])
    plt.plot(rssi_range,tot_list_area[i])
    plt.scatter(rssi_range, tot_acc_list[i])
    plt.scatter(rssi_range, tot_list_area[i])
    plt.show()
# Out:
# -63
# [0.9525691699604744, 0.9723320158102767, 0.9960474308300395, 0.9960474308300395, 1.0, 1.0]
# [0.08921592490041928, 0.09176570338332064, 0.09557980378599651, 0.09954171309025055, 0.10223385378375374, 0.10464540790690782]

# %%
thres_list = [-75]
range_val = [5]
rssi_range = [14, 16, 18, 20, 22, 24]

area_thres1 = 0.0
area_thres2 = 1.0

test_slicer = 1

model = wifimodel('하나스퀘어')

# %%
tot_acc_list = []
tot_list_area = []

tot_area_dist = []
for thres in thres_list:
    model.create_refwifi(thres)
    acc_list = []
    list_area = []
    area_dist = []
#     for rang in range_val:
    for range_for_rssi in rssi_range:
        model.define_range(range_val[0], range_for_rssi)
        cord, acc, ara, fail = model.test_all(test_slicer)
        acc_list.append(acc)
        list_area.append(ara)
        area_dist.append(model.area_list)
    tot_acc_list.append(acc_list)
    tot_list_area.append(list_area)
    tot_area_dist.append(area_dist)
# Out:
# 현재 진행 상황 : 100 회
# 성공 횟수 : 84회
# 현재 진행 상황 : 200 회
# 성공 횟수 : 175회
# 현재 진행 상황 : 300 회
# 성공 횟수 : 249회
# 현재 진행 상황 : 400 회
# 성공 횟수 : 333회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 421회
# 현재 진행 상황 : 600 회
# 성공 횟수 : 501회
# test 횟수 : 694, 성공 횟수 : 582
# 83.86167146974063
# 0.10900040219225686
# 현재 진행 상황 : 100 회
# 성공 횟수 : 84회
# 현재 진행 상황 : 200 회
# 성공 횟수 : 175회
# 현재 진행 상황 : 300 회
# 성공 횟수 : 251회
# 현재 진행 상황 : 400 회
# 성공 횟수 : 337회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 429회
# 현재 진행 상황 : 600 회
# 성공 횟수 : 517회
# test 횟수 : 694, 성공 횟수 : 602
# 86.74351585014409
# 0.1136198248050962
# 현재 진행 상황 : 100 회
# 성공 횟수 : 84회
# 현재 진행 상황 : 200 회
# 성공 횟수 : 175회
# 현재 진행 상황 : 300 회
# 성공 횟수 : 252회
# 현재 진행 상황 : 400 회
# 성공 횟수 : 340회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 432회
# 현재 진행 상황 : 600 회
# 성공 횟수 : 521회
# test 횟수 : 694, 성공 횟수 : 606
# 87.31988472622479
# 0.12389184302459649
# 현재 진행 상황 : 100 회
# 성공 횟수 : 86회
# 현재 진행 상황 : 200 회
# 성공 횟수 : 181회
# 현재 진행 상황 : 300 회
# 성공 횟수 : 261회
# 현재 진행 상황 : 400 회
# 성공 횟수 : 349회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 441회
# 현재 진행 상황 : 600 회
# 성공 횟수 : 539회
# test 횟수 : 694, 성공 횟수 : 631
# 90.92219020172911
# 0.13011887302329964
# 현재 진행 상황 : 100 회
# 성공 횟수 : 93회
# 현재 진행 상황 : 200 회
# 성공 횟수 : 188회
# 현재 진행 상황 : 300 회
# 성공 횟수 : 268회
# 현재 진행 상황 : 400 회
# 성공 횟수 : 356회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 448회
# 현재 진행 상황 : 600 회
# 성공 횟수 : 546회
# test 횟수 : 694, 성공 횟수 : 638
# 91.93083573487031
# 0.13971738901247138
# 현재 진행 상황 : 100 회
# 성공 횟수 : 93회
# 현재 진행 상황 : 200 회
# 성공 횟수 : 188회
# 현재 진행 상황 : 300 회
# 성공 횟수 : 274회
# 현재 진행 상황 : 400 회
# 성공 횟수 : 362회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 454회
# 현재 진행 상황 : 600 회
# 성공 횟수 : 552회
# test 횟수 : 694, 성공 횟수 : 644
# 92.79538904899135
# 0.14475609837493786

# %%
for i in range(len(tot_acc_list)):
    print(thres_list[i])
    print(tot_acc_list[i])
    print(tot_list_area[i])
    plt.figure(figsize = (8, 4))
    plt.plot(rssi_range,tot_acc_list[i])
    plt.plot(rssi_range,tot_list_area[i])
    plt.scatter(rssi_range, tot_acc_list[i])
    plt.scatter(rssi_range, tot_list_area[i])
    plt.show()
# Out:
# -75
# [0.8386167146974063, 0.8674351585014409, 0.8731988472622478, 0.909221902017291, 0.9193083573487032, 0.9279538904899135]
# [0.10900040219225686, 0.1136198248050962, 0.12389184302459649, 0.13011887302329964, 0.13971738901247138, 0.14475609837493786]

# %%
thres_list = [-75]
range_val = [5]
rssi_range = [32, 34, 36, 38, 40]

area_thres1 = 0.0
area_thres2 = 1.0

test_slicer = 1

model = wifimodel('하나스퀘어')

# %%
tot_acc_list = []
tot_list_area = []

tot_area_dist = []
for thres in thres_list:
    model.create_refwifi(thres)
    acc_list = []
    list_area = []
    area_dist = []
#     for rang in range_val:
    for range_for_rssi in rssi_range:
        model.define_range(range_val[0], range_for_rssi)
        cord, acc, ara, fail = model.test_all(test_slicer)
        acc_list.append(acc)
        list_area.append(ara)
        area_dist.append(model.area_list)
    tot_acc_list.append(acc_list)
    tot_list_area.append(list_area)
    tot_area_dist.append(area_dist)
# Out:
# 현재 진행 상황 : 100 회
# 성공 횟수 : 93회
# 현재 진행 상황 : 200 회
# 성공 횟수 : 190회
# 현재 진행 상황 : 300 회
# 성공 횟수 : 281회
# 현재 진행 상황 : 400 회
# 성공 횟수 : 375회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 467회
# 현재 진행 상황 : 600 회
# 성공 횟수 : 565회
# test 횟수 : 694, 성공 횟수 : 657
# 94.6685878962536
# 0.15810526916385573
# 현재 진행 상황 : 100 회
# 성공 횟수 : 93회
# 현재 진행 상황 : 200 회
# 성공 횟수 : 190회
# 현재 진행 상황 : 300 회
# 성공 횟수 : 282회
# 현재 진행 상황 : 400 회
# 성공 횟수 : 376회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 471회
# 현재 진행 상황 : 600 회
# 성공 횟수 : 569회
# test 횟수 : 694, 성공 횟수 : 661
# 95.24495677233429
# 0.16037892264437553
# 현재 진행 상황 : 100 회
# 성공 횟수 : 94회
# 현재 진행 상황 : 200 회
# 성공 횟수 : 193회
# 현재 진행 상황 : 300 회
# 성공 횟수 : 285회
# 현재 진행 상황 : 400 회
# 성공 횟수 : 379회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 474회
# 현재 진행 상황 : 600 회
# 성공 횟수 : 572회
# test 횟수 : 694, 성공 횟수 : 664
# 95.67723342939482
# 0.16275754522665647
# 현재 진행 상황 : 100 회
# 성공 횟수 : 94회
# 현재 진행 상황 : 200 회
# 성공 횟수 : 193회
# 현재 진행 상황 : 300 회
# 성공 횟수 : 286회
# 현재 진행 상황 : 400 회
# 성공 횟수 : 380회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 475회
# 현재 진행 상황 : 600 회
# 성공 횟수 : 573회
# test 횟수 : 694, 성공 횟수 : 665
# 95.82132564841498
# 0.16626129998984493
# 현재 진행 상황 : 100 회
# 성공 횟수 : 94회
# 현재 진행 상황 : 200 회
# 성공 횟수 : 193회
# 현재 진행 상황 : 300 회
# 성공 횟수 : 286회
# 현재 진행 상황 : 400 회
# 성공 횟수 : 383회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 478회
# 현재 진행 상황 : 600 회
# 성공 횟수 : 576회
# test 횟수 : 694, 성공 횟수 : 668
# 96.25360230547551
# 0.16709916387380663

# %%
for i in range(len(tot_acc_list)):
    print(thres_list[i])
    print(tot_acc_list[i])
    print(tot_list_area[i])
    plt.figure(figsize = (8, 4))
    plt.plot(rssi_range,tot_acc_list[i])
    plt.plot(rssi_range,tot_list_area[i])
    plt.scatter(rssi_range, tot_acc_list[i])
    plt.scatter(rssi_range, tot_list_area[i])
    plt.show()
# Out:
# -75
# [0.946685878962536, 0.952449567723343, 0.9567723342939481, 0.9582132564841499, 0.962536023054755]
# [0.15810526916385573, 0.16037892264437553, 0.16275754522665647, 0.16626129998984493, 0.16709916387380663]

# %%
thres_list = [-75]
range_val = [5]
rssi_range = [42, 44, 46, 48, 50]

area_thres1 = 0.0
area_thres2 = 1.0

test_slicer = 1

model = wifimodel('하나스퀘어')

# %%
tot_acc_list = []
tot_list_area = []

tot_area_dist = []
for thres in thres_list:
    model.create_refwifi(thres)
    acc_list = []
    list_area = []
    area_dist = []
#     for rang in range_val:
    for range_for_rssi in rssi_range:
        model.define_range(range_val[0], range_for_rssi)
        cord, acc, ara, fail = model.test_all(test_slicer)
        acc_list.append(acc)
        list_area.append(ara)
        area_dist.append(model.area_list)
    tot_acc_list.append(acc_list)
    tot_list_area.append(list_area)
    tot_area_dist.append(area_dist)
# Out:
# 현재 진행 상황 : 100 회
# 성공 횟수 : 94회
# 현재 진행 상황 : 200 회
# 성공 횟수 : 194회
# 현재 진행 상황 : 300 회
# 성공 횟수 : 287회
# 현재 진행 상황 : 400 회
# 성공 횟수 : 384회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 479회
# 현재 진행 상황 : 600 회
# 성공 횟수 : 577회
# test 횟수 : 694, 성공 횟수 : 669
# 96.39769452449568
# 0.17208860970025477
# 현재 진행 상황 : 100 회
# 성공 횟수 : 94회
# 현재 진행 상황 : 200 회
# 성공 횟수 : 194회
# 현재 진행 상황 : 300 회
# 성공 횟수 : 287회
# 현재 진행 상황 : 400 회
# 성공 횟수 : 384회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 479회
# 현재 진행 상황 : 600 회
# 성공 횟수 : 577회
# test 횟수 : 694, 성공 횟수 : 669
# 96.39769452449568
# 0.17435970745374327
# 현재 진행 상황 : 100 회
# 성공 횟수 : 94회
# 현재 진행 상황 : 200 회
# 성공 횟수 : 194회
# 현재 진행 상황 : 300 회
# 성공 횟수 : 287회
# 현재 진행 상황 : 400 회
# 성공 횟수 : 384회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 479회
# 현재 진행 상황 : 600 회
# 성공 횟수 : 577회
# test 횟수 : 694, 성공 횟수 : 669
# 96.39769452449568
# 0.17861682727675013
# 현재 진행 상황 : 100 회
# 성공 횟수 : 94회
# 현재 진행 상황 : 200 회
# 성공 횟수 : 194회
# 현재 진행 상황 : 300 회
# 성공 횟수 : 287회
# 현재 진행 상황 : 400 회
# 성공 횟수 : 384회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 479회
# 현재 진행 상황 : 600 회
# 성공 횟수 : 577회
# test 횟수 : 694, 성공 횟수 : 669
# 96.39769452449568
# 0.18010985077415362
# 현재 진행 상황 : 100 회
# 성공 횟수 : 94회
# 현재 진행 상황 : 200 회
# 성공 횟수 : 194회
# 현재 진행 상황 : 300 회
# 성공 횟수 : 287회
# 현재 진행 상황 : 400 회
# 성공 횟수 : 384회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 479회
# 현재 진행 상황 : 600 회
# 성공 횟수 : 579회
# test 횟수 : 694, 성공 횟수 : 671
# 96.68587896253602
# 0.1817941380372972

# %%
for i in range(len(tot_acc_list)):
    print(thres_list[i])
    print(tot_acc_list[i])
    print(tot_list_area[i])
    plt.figure(figsize = (8, 4))
    plt.plot(rssi_range,tot_acc_list[i])
    plt.plot(rssi_range,tot_list_area[i])
    plt.scatter(rssi_range, tot_acc_list[i])
    plt.scatter(rssi_range, tot_list_area[i])
    plt.show()
# Out:
# -75
# [0.9639769452449568, 0.9639769452449568, 0.9639769452449568, 0.9639769452449568, 0.9668587896253602]
# [0.17208860970025477, 0.17435970745374327, 0.17861682727675013, 0.18010985077415362, 0.1817941380372972]

# %%
thres_list = [-75]
range_val = [5]
rssi_range = [52, 54, 56, 58, 60]

area_thres1 = 0.0
area_thres2 = 1.0

test_slicer = 1

model = wifimodel('하나스퀘어')

# %%
tot_acc_list = []
tot_list_area = []

tot_area_dist = []
for thres in thres_list:
    model.create_refwifi(thres)
    acc_list = []
    list_area = []
    area_dist = []
#     for rang in range_val:
    for range_for_rssi in rssi_range:
        model.define_range(range_val[0], range_for_rssi)
        cord, acc, ara, fail = model.test_all(test_slicer)
        acc_list.append(acc)
        list_area.append(ara)
        area_dist.append(model.area_list)
    tot_acc_list.append(acc_list)
    tot_list_area.append(list_area)
    tot_area_dist.append(area_dist)
# Out:
# 현재 진행 상황 : 100 회
# 성공 횟수 : 95회
# 현재 진행 상황 : 200 회
# 성공 횟수 : 195회
# 현재 진행 상황 : 300 회
# 성공 횟수 : 290회
# 현재 진행 상황 : 400 회
# 성공 횟수 : 387회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 482회
# 현재 진행 상황 : 600 회
# 성공 횟수 : 582회
# test 횟수 : 694, 성공 횟수 : 676
# 97.40634005763688
# 0.18364372112424512
# 현재 진행 상황 : 100 회
# 성공 횟수 : 95회
# 현재 진행 상황 : 200 회
# 성공 횟수 : 195회
# 현재 진행 상황 : 300 회
# 성공 횟수 : 290회
# 현재 진행 상황 : 400 회
# 성공 횟수 : 389회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 484회
# 현재 진행 상황 : 600 회
# 성공 횟수 : 584회
# test 횟수 : 694, 성공 횟수 : 678
# 97.69452449567723
# 0.18605117675017893
# 현재 진행 상황 : 100 회
# 성공 횟수 : 95회
# 현재 진행 상황 : 200 회
# 성공 횟수 : 195회
# 현재 진행 상황 : 300 회
# 성공 횟수 : 290회
# 현재 진행 상황 : 400 회
# 성공 횟수 : 389회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 484회
# 현재 진행 상황 : 600 회
# 성공 횟수 : 584회
# test 횟수 : 694, 성공 횟수 : 678
# 97.69452449567723
# 0.18849036925237392
# 현재 진행 상황 : 100 회
# 성공 횟수 : 95회
# 현재 진행 상황 : 200 회
# 성공 횟수 : 195회
# 현재 진행 상황 : 300 회
# 성공 횟수 : 294회
# 현재 진행 상황 : 400 회
# 성공 횟수 : 393회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 488회
# 현재 진행 상황 : 600 회
# 성공 횟수 : 588회
# test 횟수 : 694, 성공 횟수 : 682
# 98.27089337175792
# 0.1910367083273213
# 현재 진행 상황 : 100 회
# 성공 횟수 : 95회
# 현재 진행 상황 : 200 회
# 성공 횟수 : 195회
# 현재 진행 상황 : 300 회
# 성공 횟수 : 294회
# 현재 진행 상황 : 400 회
# 성공 횟수 : 393회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 488회
# 현재 진행 상황 : 600 회
# 성공 횟수 : 588회
# test 횟수 : 694, 성공 횟수 : 682
# 98.27089337175792
# 0.19335930915438695

# %%
for i in range(len(tot_acc_list)):
    print(thres_list[i])
    print(tot_acc_list[i])
    print(tot_list_area[i])
    plt.figure(figsize = (8, 4))
    plt.plot(rssi_range,tot_acc_list[i])
    plt.plot(rssi_range,tot_list_area[i])
    plt.scatter(rssi_range, tot_acc_list[i])
    plt.scatter(rssi_range, tot_list_area[i])
    plt.show()
# Out:
# -75
# [0.9740634005763689, 0.9769452449567724, 0.9769452449567724, 0.9827089337175793, 0.9827089337175793]
# [0.18364372112424512, 0.18605117675017893, 0.18849036925237392, 0.1910367083273213, 0.19335930915438695]

# %%
thres_list = [-75]
range_val = [5]
rssi_range = [62, 64, 66, 68, 70]

area_thres1 = 0.0
area_thres2 = 1.0

test_slicer = 1

model = wifimodel('하나스퀘어')

# %%
tot_acc_list = []
tot_list_area = []

tot_area_dist = []
for thres in thres_list:
    model.create_refwifi(thres)
    acc_list = []
    list_area = []
    area_dist = []
#     for rang in range_val:
    for range_for_rssi in rssi_range:
        model.define_range(range_val[0], range_for_rssi)
        cord, acc, ara, fail = model.test_all(test_slicer)
        acc_list.append(acc)
        list_area.append(ara)
        area_dist.append(model.area_list)
    tot_acc_list.append(acc_list)
    tot_list_area.append(list_area)
    tot_area_dist.append(area_dist)
# Out:
# 현재 진행 상황 : 100 회
# 성공 횟수 : 95회
# 현재 진행 상황 : 200 회
# 성공 횟수 : 195회
# 현재 진행 상황 : 300 회
# 성공 횟수 : 294회
# 현재 진행 상황 : 400 회
# 성공 횟수 : 393회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 488회
# 현재 진행 상황 : 600 회
# 성공 횟수 : 588회
# test 횟수 : 694, 성공 횟수 : 682
# 98.27089337175792
# 0.1955388019323358
# 현재 진행 상황 : 100 회
# 성공 횟수 : 95회
# 현재 진행 상황 : 200 회
# 성공 횟수 : 195회
# 현재 진행 상황 : 300 회
# 성공 횟수 : 294회
# 현재 진행 상황 : 400 회
# 성공 횟수 : 393회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 488회
# 현재 진행 상황 : 600 회
# 성공 횟수 : 588회
# test 횟수 : 694, 성공 횟수 : 682
# 98.27089337175792
# 0.19706039520670598
# 현재 진행 상황 : 100 회
# 성공 횟수 : 95회
# 현재 진행 상황 : 200 회
# 성공 횟수 : 195회
# 현재 진행 상황 : 300 회
# 성공 횟수 : 294회
# 현재 진행 상황 : 400 회
# 성공 횟수 : 393회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 488회
# 현재 진행 상황 : 600 회
# 성공 횟수 : 588회
# test 횟수 : 694, 성공 횟수 : 682
# 98.27089337175792
# 0.20037190934754037
# 현재 진행 상황 : 100 회
# 성공 횟수 : 95회
# 현재 진행 상황 : 200 회
# 성공 횟수 : 195회
# 현재 진행 상황 : 300 회
# 성공 횟수 : 294회
# 현재 진행 상황 : 400 회
# 성공 횟수 : 393회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 488회
# 현재 진행 상황 : 600 회
# 성공 횟수 : 588회
# test 횟수 : 694, 성공 횟수 : 682
# 98.27089337175792
# 0.20378891980663388
# 현재 진행 상황 : 100 회
# 성공 횟수 : 95회
# 현재 진행 상황 : 200 회
# 성공 횟수 : 195회
# 현재 진행 상황 : 300 회
# 성공 횟수 : 294회
# 현재 진행 상황 : 400 회
# 성공 횟수 : 393회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 488회
# 현재 진행 상황 : 600 회
# 성공 횟수 : 588회
# test 횟수 : 694, 성공 횟수 : 682
# 98.27089337175792
# 0.20469389474543986

# %%
for i in range(len(tot_acc_list)):
    print(thres_list[i])
    print(tot_acc_list[i])
    print(tot_list_area[i])
    plt.figure(figsize = (8, 4))
    plt.plot(rssi_range,tot_acc_list[i])
    plt.plot(rssi_range,tot_list_area[i])
    plt.scatter(rssi_range, tot_acc_list[i])
    plt.scatter(rssi_range, tot_list_area[i])
    plt.show()
# Out:
# -75
# [0.9827089337175793, 0.9827089337175793, 0.9827089337175793, 0.9827089337175793, 0.9827089337175793]
# [0.1955388019323358, 0.19706039520670598, 0.20037190934754037, 0.20378891980663388, 0.20469389474543986]

# %%
# for f in fail:
#     x_list = f[2][0]
#     y_list = f[2][1]

#     x = f[0]
#     y = f[1]
    
#     print(x, y)

#     plt.figure(figsize = (15, 11))
#     plt.imshow(model.mag_df, cmap='jet', interpolation='none')
#     plt.scatter(y_list, x_list, c = 'b')
#     plt.scatter(y, x, c = 'r')

#     plt.show()
