# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import copy
import time
import os

# %%
class wifimodel():
    def __init__(self, location):
        self.train_dir = f'../data/{location}/train/'
        self.test_dir = f'../data/{location}/test/'
        self.model_df = pd.DataFrame()
        self.test_df = pd.DataFrame()

        self.fil_model_df = pd.DataFrame()
        self.fil_test_df = pd.DataFrame()

        self.SSID_list = []
        
        self.test_x_list = []
        self.test_y_list = []
        
        self.maxarea = 0
        self.maxarea2 = 0
        self.refwifi = []

        self.rssi_thres = 0
        self.range_num = 0
        self.range_num2 = 0

        file_list = os.listdir(self.train_dir)
        for file in file_list:
            df = pd.read_csv(self.train_dir + file,
                             sep="\t", engine='python', encoding="UTF-8", header=None)
            df = pd.DataFrame(
                {"cnt": list(df.iloc[:, 0]), "x": list(df.iloc[:, 1]), "y": list(df.iloc[:, 2]),
                 "ADDR": list(df.iloc[:, 3]),
                 "SSID": list(df.iloc[:, 4]),
                 "RSSI": list(df.iloc[:, 5])})
            self.model_df = pd.concat([self.model_df, df])

        file_list = os.listdir(self.test_dir)
        for file in file_list:
            df = pd.read_csv(self.test_dir + file,
                             sep="\t", engine='python', encoding="UTF-8", header=None)
            df = pd.DataFrame(
                {"cnt": list(df.iloc[:, 0]), "x": list(df.iloc[:, 1]), "y": list(df.iloc[:, 2]),
                 "ADDR": list(df.iloc[:, 3]),
                 "SSID": list(df.iloc[:, 4]),
                 "RSSI": list(df.iloc[:, 5])})
            self.test_df = pd.concat([self.test_df, df])
        
        self.mag_df = pd.read_csv(f'../mag/{location}/magx.txt', sep="\t", engine='python', encoding="cp949", header=None)

        self.ref_mag_df = copy.deepcopy(self.mag_df)
        
        for i in range(self.mag_df.shape[0]):
            for j in range(self.mag_df.shape[1]):
                if ((i % 6 == 0 ) and (j % 6 == 0) and (self.mag_df.iloc[i, j] != 0.0)):
                    self.maxarea += 1
        
        self.maxarea2 = sum(self.ref_mag_df[self.ref_mag_df != 0.0].count())
        self.mag_df[self.mag_df != 0.0] = np.nan

        self.maxX = self.mag_df.shape[0]
        self.maxY = self.mag_df.shape[1]

    def cal_area(self, posx, posy):
        cnt = 0
        temp = self.ref_mag_df.iloc[int(min(posx)): int(max(posx)), int(min(posy)): int(max(posy))]
        return sum(temp[temp != 0.0].count())
    
    def cal_area2(self, posx, posy):
        cnt = 0
        for i in range(len(posx)):
            if self.mag_df.iloc[posx[i], posy[i]] != 0.0:
                cnt += 1
        return cnt
    
    def define_range(self, range_num, range_num2):
        self.range_num = range_num
        self.range_num2 = range_num2
    
    def create_refwifi(self, rssi_thres):
        self.rssi_thres = rssi_thres
        
        fil_model_df = self.model_df.loc[self.model_df['RSSI'] >= self.rssi_thres]
        self.fil_test_df = self.test_df.loc[self.test_df['RSSI'] >= self.rssi_thres]

        self.SSID_list = list(fil_model_df['SSID'].unique())
        self.test_x_list = self.fil_test_df['x'].unique()
        self.test_y_list = self.fil_test_df['y'].unique()
        
        self.refwifi = np.zeros((self.maxX, self.maxY, len(self.SSID_list)), dtype = np.int64)
        
        for i in range(fil_model_df.shape[0]):
            posx = fil_model_df.iloc[i, 1]
            posy = fil_model_df.iloc[i, 2]
            ssid = fil_model_df.iloc[i, 4]
            rssi = fil_model_df.iloc[i, 5]
            if(0 <= posx < self.maxX) and (0 <= posy < self.maxY):
                self.refwifi[int(posx)][int(posy)][self.SSID_list.index(ssid)] \
                    = 1

    def test_all(self, test_slicer):
        tot_cnt = 0
        cnt = 0
        self.area_list = []
        coords_list = []
        fail_list = []
        
        test_num_cnt = 0

        for x in self.test_x_list:
            for y in self.test_y_list:
                if test_num_cnt % test_slicer == 0:
                    compare_list = np.array([0 for i in range(len(self.SSID_list))])
                    compare_df = self.fil_test_df.loc[(self.fil_test_df["x"] == x) & (self.fil_test_df["y"] == y)]
                    if compare_df.empty == False:
                        for i in range(compare_df.shape[0]):
                            if (compare_df.iloc[i, 4] in self.SSID_list):
                                compare_list[self.SSID_list.index(compare_df.iloc[i, 4])] = -1

                        temp_wifi = self.refwifi - compare_list
                        temp_wifi = np.where(temp_wifi == 1, 0, temp_wifi)

                        sum_temp = temp_wifi.sum(axis=2)
                        sum_np = np.unique(sum_temp.flatten())[:: -1]

                        if len(sum_np) <= self.range_num:
                            range_idx = len(sum_np) - 1
                        else:
                            range_idx = self.range_num

                        if range_idx == -1:
                            rangeval = 0
                        else:
                            rangeval = np.unique(sum_np)[:: - 1][range_idx]

                        coords = np.where(sum_temp >= rangeval)

                        if (min(coords[0]) <= x <= max(coords[0]) and min(coords[1]) <= y <= max(coords[1])):
                            cnt += 1
                            coords_list.append([x, y, coords])
                            self.area_list.append((max(coords[0]) - min(coords[0])) * (max(coords[1]) - min(coords[1]))
                                                  / (self.maxX * self.maxY))
                        else:
                            fail_list.append([x, y, coords])
                        tot_cnt += 1
                    
                test_num_cnt += 1
                if (tot_cnt % 50 == 0):
                    print(f"현재 진행 상황 : {tot_cnt} 회")
                    print(f"성공 횟수 : {cnt}회")

        print(f"test 횟수 : {tot_cnt}, 성공 횟수 : {cnt}")
        print(cnt * 100 / tot_cnt)
        print(np.average(self.area_list))
        
        return coords_list, cnt / tot_cnt, np.average(self.area_list), fail_list
        
    
    def test_one(self, idx):
        tot_cnt = 0
        cnt = 0
        self.area_list = []
        coords_list = []
        
        self.fil_test_df['x_y'] = self.fil_test_df['x'].astype('str') + "\t" + self.fil_test_df['y'].astype('str')
        test_list = list(self.fil_test_df['x_y'].unique())[idx].split('\t')
        
        x = float(test_list[0])
        y = float(test_list[1])
        
        compare_list = np.array([0 for i in range(len(self.SSID_list))])
        compare_df = self.fil_test_df.loc[(self.fil_test_df["x"] == x) & (self.fil_test_df["y"] == y)]
        
        
        if compare_df.empty == False:
            for i in range(compare_df.shape[0]):
                if (compare_df.iloc[i, 4] in self.SSID_list):
                    compare_list[self.SSID_list.index(compare_df.iloc[i, 4])] = -1

            temp_wifi = self.refwifi - compare_list
            temp_wifi = np.where(temp_wifi == 1, 0, temp_wifi)

            sum_temp = temp_wifi.sum(axis=2)
            sum_np = np.unique(sum_temp.flatten())[:: -1]

            if len(sum_np) <= self.range_num:
                range_idx = len(sum_np) - 1
            else:
                range_idx = self.range_num

            if range_idx == -1:
                rangeval = 0
            else:
                rangeval = np.unique(sum_np)[:: - 1][range_idx]

            coords = np.where(sum_temp >= rangeval)
            coords_list.append([x, y, coords])
            self.area_list.append((max(coords[0]) - min(coords[0])) * (max(coords[1]) - min(coords[1]))
                      / (self.maxX * self.maxY))
        
        return coords_list, x, y,coords, sum_np
    
    def save_refwifi(self):
        file_name = f'../wifihashmap/{self.location}/wifihashmap.txt'

        path_save = open(file_name, 'w')

        for x in range(self.maxX + 1):
            for y in range(self.maxY + 1):
                if(x % 6 == 0) and (y % 6 == 0):
                    content = str(x) + "\t" + str(y) + "\t" + "".join(list(map(str, self.refwifi[x][y]))) + "\n"
                    path_save.write(content)
        path_save.close()
        
        file_name = f'../wifihashmap/{self.location}/wifilist.txt'

        path_save = open(file_name, 'w')

        content = "\t".join(self.SSID_list)
        path_save.write(content)
        path_save.close()

# %%
train_dir = './pastdata/newaugdata/'
test_dir = './pastdata/augdata2/test/'

ref_mag_dir = '../handmagx.txt'

thres_list = [-75, -78, -81, -84, -87, -90]
range_val = [2, 4, 6 ,8]
range_val2 = [1, 1, 2, 2, 3]
area_thres1 = 0.0
area_thres2 = 1.0

test_slicer = 1

model = wifimodel(train_dir, test_dir, ref_mag_dir)

# %%
tot_acc_list = []
tot_list_area = []

tot_area_dist = []
for thres in thres_list:
    model.create_refwifi(thres)
    acc_list = []
    list_area = []
    area_dist = []
    for rang in range_val:
        model.define_range(rang, rang)
        cord, acc, ara, fail = model.test_all(test_slicer)
        acc_list.append(acc)
        list_area.append(ara)
        area_dist.append(model.area_list)
    tot_acc_list.append(acc_list)
    tot_list_area.append(list_area)
    tot_area_dist.append(area_dist)
# Out:
# 현재 진행 상황 : 50 회
# 성공 횟수 : 40회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 82회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 82회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 82회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 82회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 82회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 82회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 82회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 82회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 82회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 82회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 82회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 82회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 82회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 82회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 82회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 82회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 82회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 82회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 82회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 82회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 82회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 82회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 82회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 82회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 82회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 82회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 82회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 82회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 82회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 82회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 82회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 82회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 82회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 82회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 82회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 82회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 82회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 82회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 82회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 82회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 82회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 82회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 82회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 82회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 82회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 82회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 82회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 82회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 82회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 82회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 82회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 82회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 82회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 82회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 82회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 82회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 82회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 82회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 82회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 82회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 82회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 82회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 82회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 82회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 82회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 82회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 82회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 82회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 82회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 82회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 82회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 82회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 82회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 82회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 82회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 82회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 82회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 82회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 82회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 82회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 82회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 82회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 82회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 82회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 82회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 82회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 82회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 82회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 82회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 82회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 82회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 82회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 82회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 82회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 82회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 82회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 82회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 82회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 82회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 82회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 82회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 82회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 82회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 82회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 82회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 82회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 82회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 82회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 82회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 82회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 82회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 82회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 82회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 82회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 82회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 82회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 82회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 82회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 82회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 82회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 82회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 82회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 82회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 82회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 82회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 82회
# 현재 진행 상황 : 150 회
# 성공 횟수 : 122회
# 현재 진행 상황 : 200 회
# 성공 횟수 : 154회
# 현재 진행 상황 : 250 회
# 성공 횟수 : 190회
# 현재 진행 상황 : 250 회
# 성공 횟수 : 190회
# 현재 진행 상황 : 250 회
# 성공 횟수 : 190회
# 현재 진행 상황 : 250 회
# 성공 횟수 : 190회
# 현재 진행 상황 : 250 회
# 성공 횟수 : 190회
# 현재 진행 상황 : 250 회
# 성공 횟수 : 190회
# 현재 진행 상황 : 250 회
# 성공 횟수 : 190회
# 현재 진행 상황 : 250 회
# 성공 횟수 : 190회
# 현재 진행 상황 : 250 회
# 성공 횟수 : 190회
# 현재 진행 상황 : 300 회
# 성공 횟수 : 232회
# 현재 진행 상황 : 350 회
# 성공 횟수 : 271회
# 현재 진행 상황 : 400 회
# 성공 횟수 : 320회
# 현재 진행 상황 : 450 회
# 성공 횟수 : 367회
# 현재 진행 상황 : 450 회
# 성공 횟수 : 367회
# 현재 진행 상황 : 450 회
# 성공 횟수 : 367회
# 현재 진행 상황 : 450 회
# 성공 횟수 : 367회
# 현재 진행 상황 : 450 회
# 성공 횟수 : 367회
# 현재 진행 상황 : 450 회
# 성공 횟수 : 367회
# 현재 진행 상황 : 450 회
# 성공 횟수 : 367회
# 현재 진행 상황 : 450 회
# 성공 횟수 : 367회
# 현재 진행 상황 : 450 회
# 성공 횟수 : 367회
# 현재 진행 상황 : 450 회
# 성공 횟수 : 367회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 410회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 410회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 410회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 410회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 410회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 410회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 410회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 410회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 410회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 410회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 410회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 410회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 410회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 410회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 410회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 410회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 410회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 410회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 410회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 410회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 410회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 410회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 410회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 410회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 410회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 410회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 410회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 410회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 410회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 410회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 410회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 410회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 410회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 410회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 410회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 410회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 410회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 410회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 410회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 410회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 410회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 410회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 410회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 410회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 410회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 410회
# 현재 진행 상황 : 550 회
# 성공 횟수 : 448회
# 현재 진행 상황 : 600 회
# 성공 횟수 : 494회
# 현재 진행 상황 : 650 회
# 성공 횟수 : 539회
# test 횟수 : 694, 성공 횟수 : 576
# 82.9971181556196
# 0.15816556697089332
# 현재 진행 상황 : 50 회
# 성공 횟수 : 46회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 95회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 95회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 95회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 95회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 95회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 95회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 95회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 95회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 95회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 95회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 95회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 95회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 95회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 95회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 95회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 95회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 95회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 95회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 95회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 95회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 95회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 95회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 95회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 95회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 95회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 95회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 95회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 95회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 95회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 95회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 95회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 95회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 95회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 95회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 95회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 95회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 95회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 95회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 95회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 95회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 95회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 95회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 95회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 95회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 95회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 95회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 95회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 95회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 95회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 95회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 95회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 95회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 95회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 95회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 95회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 95회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 95회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 95회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 95회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 95회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 95회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 95회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 95회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 95회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 95회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 95회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 95회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 95회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 95회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 95회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 95회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 95회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 95회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 95회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 95회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 95회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 95회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 95회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 95회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 95회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 95회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 95회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 95회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 95회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 95회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 95회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 95회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 95회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 95회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 95회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 95회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 95회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 95회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 95회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 95회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 95회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 95회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 95회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 95회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 95회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 95회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 95회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 95회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 95회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 95회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 95회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 95회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 95회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 95회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 95회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 95회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 95회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 95회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 95회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 95회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 95회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 95회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 95회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 95회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 95회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 95회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 95회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 95회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 95회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 95회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 95회
# 현재 진행 상황 : 150 회
# 성공 횟수 : 145회
# 현재 진행 상황 : 200 회
# 성공 횟수 : 189회
# 현재 진행 상황 : 250 회
# 성공 횟수 : 234회
# 현재 진행 상황 : 250 회
# 성공 횟수 : 234회
# 현재 진행 상황 : 250 회
# 성공 횟수 : 234회
# 현재 진행 상황 : 250 회
# 성공 횟수 : 234회
# 현재 진행 상황 : 250 회
# 성공 횟수 : 234회
# 현재 진행 상황 : 250 회
# 성공 횟수 : 234회
# 현재 진행 상황 : 250 회
# 성공 횟수 : 234회
# 현재 진행 상황 : 250 회
# 성공 횟수 : 234회
# 현재 진행 상황 : 250 회
# 성공 횟수 : 234회
# 현재 진행 상황 : 300 회
# 성공 횟수 : 283회
# 현재 진행 상황 : 350 회
# 성공 횟수 : 333회
# 현재 진행 상황 : 400 회
# 성공 횟수 : 382회
# 현재 진행 상황 : 450 회
# 성공 횟수 : 429회
# 현재 진행 상황 : 450 회
# 성공 횟수 : 429회
# 현재 진행 상황 : 450 회
# 성공 횟수 : 429회
# 현재 진행 상황 : 450 회
# 성공 횟수 : 429회
# 현재 진행 상황 : 450 회
# 성공 횟수 : 429회
# 현재 진행 상황 : 450 회
# 성공 횟수 : 429회
# 현재 진행 상황 : 450 회
# 성공 횟수 : 429회
# 현재 진행 상황 : 450 회
# 성공 횟수 : 429회
# 현재 진행 상황 : 450 회
# 성공 횟수 : 429회
# 현재 진행 상황 : 450 회
# 성공 횟수 : 429회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 477회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 477회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 477회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 477회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 477회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 477회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 477회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 477회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 477회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 477회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 477회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 477회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 477회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 477회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 477회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 477회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 477회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 477회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 477회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 477회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 477회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 477회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 477회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 477회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 477회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 477회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 477회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 477회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 477회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 477회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 477회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 477회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 477회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 477회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 477회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 477회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 477회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 477회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 477회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 477회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 477회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 477회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 477회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 477회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 477회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 477회
# 현재 진행 상황 : 550 회
# 성공 횟수 : 527회
# 현재 진행 상황 : 600 회
# 성공 횟수 : 577회
# 현재 진행 상황 : 650 회
# 성공 횟수 : 627회
# test 횟수 : 694, 성공 횟수 : 669
# 96.39769452449568
# 0.2448201606645927
# 현재 진행 상황 : 50 회
# 성공 횟수 : 47회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 150 회
# 성공 횟수 : 147회
# 현재 진행 상황 : 200 회
# 성공 횟수 : 197회
# 현재 진행 상황 : 250 회
# 성공 횟수 : 247회
# 현재 진행 상황 : 250 회
# 성공 횟수 : 247회
# 현재 진행 상황 : 250 회
# 성공 횟수 : 247회
# 현재 진행 상황 : 250 회
# 성공 횟수 : 247회
# 현재 진행 상황 : 250 회
# 성공 횟수 : 247회
# 현재 진행 상황 : 250 회
# 성공 횟수 : 247회
# 현재 진행 상황 : 250 회
# 성공 횟수 : 247회
# 현재 진행 상황 : 250 회
# 성공 횟수 : 247회
# 현재 진행 상황 : 250 회
# 성공 횟수 : 247회
# 현재 진행 상황 : 300 회
# 성공 횟수 : 296회
# 현재 진행 상황 : 350 회
# 성공 횟수 : 346회
# 현재 진행 상황 : 400 회
# 성공 횟수 : 395회
# 현재 진행 상황 : 450 회
# 성공 횟수 : 442회
# 현재 진행 상황 : 450 회
# 성공 횟수 : 442회
# 현재 진행 상황 : 450 회
# 성공 횟수 : 442회
# 현재 진행 상황 : 450 회
# 성공 횟수 : 442회
# 현재 진행 상황 : 450 회
# 성공 횟수 : 442회
# 현재 진행 상황 : 450 회
# 성공 횟수 : 442회
# 현재 진행 상황 : 450 회
# 성공 횟수 : 442회
# 현재 진행 상황 : 450 회
# 성공 횟수 : 442회
# 현재 진행 상황 : 450 회
# 성공 횟수 : 442회
# 현재 진행 상황 : 450 회
# 성공 횟수 : 442회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 490회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 490회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 490회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 490회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 490회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 490회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 490회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 490회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 490회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 490회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 490회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 490회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 490회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 490회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 490회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 490회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 490회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 490회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 490회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 490회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 490회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 490회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 490회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 490회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 490회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 490회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 490회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 490회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 490회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 490회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 490회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 490회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 490회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 490회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 490회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 490회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 490회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 490회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 490회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 490회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 490회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 490회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 490회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 490회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 490회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 490회
# 현재 진행 상황 : 550 회
# 성공 횟수 : 540회
# 현재 진행 상황 : 600 회
# 성공 횟수 : 590회
# 현재 진행 상황 : 650 회
# 성공 횟수 : 640회
# test 횟수 : 694, 성공 횟수 : 684
# 98.55907780979827
# 0.30507464297490755
# 현재 진행 상황 : 50 회
# 성공 횟수 : 47회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 150 회
# 성공 횟수 : 147회
# 현재 진행 상황 : 200 회
# 성공 횟수 : 197회
# 현재 진행 상황 : 250 회
# 성공 횟수 : 247회
# 현재 진행 상황 : 250 회
# 성공 횟수 : 247회
# 현재 진행 상황 : 250 회
# 성공 횟수 : 247회
# 현재 진행 상황 : 250 회
# 성공 횟수 : 247회
# 현재 진행 상황 : 250 회
# 성공 횟수 : 247회
# 현재 진행 상황 : 250 회
# 성공 횟수 : 247회
# 현재 진행 상황 : 250 회
# 성공 횟수 : 247회
# 현재 진행 상황 : 250 회
# 성공 횟수 : 247회
# 현재 진행 상황 : 250 회
# 성공 횟수 : 247회
# 현재 진행 상황 : 300 회
# 성공 횟수 : 297회
# 현재 진행 상황 : 350 회
# 성공 횟수 : 347회
# 현재 진행 상황 : 400 회
# 성공 횟수 : 397회
# 현재 진행 상황 : 450 회
# 성공 횟수 : 447회
# 현재 진행 상황 : 450 회
# 성공 횟수 : 447회
# 현재 진행 상황 : 450 회
# 성공 횟수 : 447회
# 현재 진행 상황 : 450 회
# 성공 횟수 : 447회
# 현재 진행 상황 : 450 회
# 성공 횟수 : 447회
# 현재 진행 상황 : 450 회
# 성공 횟수 : 447회
# 현재 진행 상황 : 450 회
# 성공 횟수 : 447회
# 현재 진행 상황 : 450 회
# 성공 횟수 : 447회
# 현재 진행 상황 : 450 회
# 성공 횟수 : 447회
# 현재 진행 상황 : 450 회
# 성공 횟수 : 447회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 497회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 497회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 497회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 497회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 497회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 497회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 497회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 497회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 497회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 497회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 497회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 497회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 497회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 497회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 497회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 497회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 497회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 497회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 497회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 497회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 497회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 497회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 497회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 497회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 497회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 497회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 497회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 497회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 497회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 497회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 497회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 497회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 497회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 497회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 497회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 497회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 497회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 497회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 497회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 497회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 497회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 497회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 497회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 497회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 497회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 497회
# 현재 진행 상황 : 550 회
# 성공 횟수 : 547회
# 현재 진행 상황 : 600 회
# 성공 횟수 : 597회
# 현재 진행 상황 : 650 회
# 성공 횟수 : 647회
# test 횟수 : 694, 성공 횟수 : 691
# 99.56772334293949
# 0.36458533806604543
# 현재 진행 상황 : 50 회
# 성공 횟수 : 34회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 71회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 71회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 71회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 71회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 71회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 71회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 71회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 71회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 71회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 71회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 71회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 71회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 71회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 71회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 71회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 71회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 71회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 71회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 71회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 71회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 71회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 71회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 71회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 71회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 71회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 71회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 71회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 71회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 71회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 71회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 71회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 71회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 71회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 71회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 71회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 71회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 71회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 71회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 71회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 71회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 71회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 71회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 71회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 71회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 71회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 71회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 71회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 71회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 71회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 71회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 71회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 71회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 71회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 71회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 71회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 71회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 71회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 71회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 71회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 71회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 71회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 71회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 71회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 71회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 71회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 71회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 71회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 71회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 71회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 71회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 71회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 71회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 71회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 71회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 71회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 71회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 71회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 71회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 71회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 71회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 71회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 71회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 71회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 71회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 71회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 71회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 71회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 71회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 71회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 71회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 71회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 71회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 71회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 71회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 71회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 71회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 71회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 71회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 71회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 71회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 71회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 71회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 71회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 71회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 71회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 71회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 71회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 71회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 71회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 71회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 71회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 71회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 71회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 71회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 71회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 71회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 71회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 71회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 71회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 71회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 71회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 71회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 71회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 71회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 71회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 71회
# 현재 진행 상황 : 150 회
# 성공 횟수 : 109회
# 현재 진행 상황 : 200 회
# 성공 횟수 : 147회
# 현재 진행 상황 : 250 회
# 성공 횟수 : 188회
# 현재 진행 상황 : 250 회
# 성공 횟수 : 188회
# 현재 진행 상황 : 250 회
# 성공 횟수 : 188회
# 현재 진행 상황 : 250 회
# 성공 횟수 : 188회
# 현재 진행 상황 : 250 회
# 성공 횟수 : 188회
# 현재 진행 상황 : 250 회
# 성공 횟수 : 188회
# 현재 진행 상황 : 250 회
# 성공 횟수 : 188회
# 현재 진행 상황 : 250 회
# 성공 횟수 : 188회
# 현재 진행 상황 : 250 회
# 성공 횟수 : 188회
# 현재 진행 상황 : 300 회
# 성공 횟수 : 224회
# 현재 진행 상황 : 350 회
# 성공 횟수 : 259회
# 현재 진행 상황 : 400 회
# 성공 횟수 : 297회
# 현재 진행 상황 : 450 회
# 성공 횟수 : 340회
# 현재 진행 상황 : 450 회
# 성공 횟수 : 340회
# 현재 진행 상황 : 450 회
# 성공 횟수 : 340회
# 현재 진행 상황 : 450 회
# 성공 횟수 : 340회
# 현재 진행 상황 : 450 회
# 성공 횟수 : 340회
# 현재 진행 상황 : 450 회
# 성공 횟수 : 340회
# 현재 진행 상황 : 450 회
# 성공 횟수 : 340회
# 현재 진행 상황 : 450 회
# 성공 횟수 : 340회
# 현재 진행 상황 : 450 회
# 성공 횟수 : 340회
# 현재 진행 상황 : 450 회
# 성공 횟수 : 340회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 382회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 382회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 382회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 382회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 382회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 382회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 382회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 382회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 382회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 382회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 382회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 382회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 382회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 382회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 382회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 382회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 382회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 382회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 382회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 382회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 382회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 382회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 382회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 382회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 382회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 382회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 382회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 382회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 382회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 382회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 382회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 382회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 382회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 382회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 382회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 382회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 382회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 382회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 382회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 382회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 382회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 382회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 382회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 382회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 382회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 382회
# 현재 진행 상황 : 550 회
# 성공 횟수 : 425회
# 현재 진행 상황 : 600 회
# 성공 횟수 : 461회
# 현재 진행 상황 : 650 회
# 성공 횟수 : 499회
# test 횟수 : 694, 성공 횟수 : 527
# 75.93659942363112
# 0.14882215421724113
# 현재 진행 상황 : 50 회
# 성공 횟수 : 44회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 94회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 94회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 94회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 94회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 94회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 94회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 94회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 94회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 94회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 94회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 94회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 94회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 94회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 94회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 94회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 94회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 94회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 94회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 94회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 94회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 94회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 94회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 94회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 94회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 94회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 94회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 94회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 94회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 94회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 94회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 94회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 94회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 94회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 94회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 94회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 94회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 94회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 94회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 94회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 94회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 94회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 94회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 94회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 94회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 94회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 94회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 94회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 94회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 94회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 94회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 94회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 94회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 94회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 94회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 94회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 94회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 94회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 94회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 94회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 94회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 94회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 94회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 94회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 94회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 94회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 94회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 94회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 94회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 94회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 94회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 94회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 94회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 94회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 94회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 94회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 94회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 94회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 94회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 94회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 94회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 94회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 94회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 94회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 94회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 94회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 94회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 94회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 94회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 94회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 94회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 94회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 94회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 94회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 94회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 94회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 94회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 94회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 94회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 94회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 94회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 94회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 94회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 94회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 94회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 94회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 94회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 94회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 94회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 94회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 94회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 94회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 94회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 94회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 94회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 94회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 94회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 94회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 94회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 94회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 94회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 94회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 94회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 94회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 94회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 94회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 94회
# 현재 진행 상황 : 150 회
# 성공 횟수 : 139회
# 현재 진행 상황 : 200 회
# 성공 횟수 : 189회
# 현재 진행 상황 : 250 회
# 성공 횟수 : 235회
# 현재 진행 상황 : 250 회
# 성공 횟수 : 235회
# 현재 진행 상황 : 250 회
# 성공 횟수 : 235회
# 현재 진행 상황 : 250 회
# 성공 횟수 : 235회
# 현재 진행 상황 : 250 회
# 성공 횟수 : 235회
# 현재 진행 상황 : 250 회
# 성공 횟수 : 235회
# 현재 진행 상황 : 250 회
# 성공 횟수 : 235회
# 현재 진행 상황 : 250 회
# 성공 횟수 : 235회
# 현재 진행 상황 : 250 회
# 성공 횟수 : 235회
# 현재 진행 상황 : 300 회
# 성공 횟수 : 279회
# 현재 진행 상황 : 350 회
# 성공 횟수 : 329회
# 현재 진행 상황 : 400 회
# 성공 횟수 : 378회
# 현재 진행 상황 : 450 회
# 성공 횟수 : 425회
# 현재 진행 상황 : 450 회
# 성공 횟수 : 425회
# 현재 진행 상황 : 450 회
# 성공 횟수 : 425회
# 현재 진행 상황 : 450 회
# 성공 횟수 : 425회
# 현재 진행 상황 : 450 회
# 성공 횟수 : 425회
# 현재 진행 상황 : 450 회
# 성공 횟수 : 425회
# 현재 진행 상황 : 450 회
# 성공 횟수 : 425회
# 현재 진행 상황 : 450 회
# 성공 횟수 : 425회
# 현재 진행 상황 : 450 회
# 성공 횟수 : 425회
# 현재 진행 상황 : 450 회
# 성공 횟수 : 425회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 471회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 471회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 471회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 471회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 471회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 471회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 471회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 471회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 471회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 471회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 471회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 471회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 471회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 471회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 471회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 471회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 471회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 471회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 471회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 471회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 471회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 471회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 471회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 471회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 471회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 471회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 471회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 471회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 471회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 471회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 471회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 471회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 471회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 471회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 471회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 471회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 471회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 471회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 471회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 471회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 471회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 471회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 471회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 471회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 471회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 471회
# 현재 진행 상황 : 550 회
# 성공 횟수 : 521회
# 현재 진행 상황 : 600 회
# 성공 횟수 : 571회
# 현재 진행 상황 : 650 회
# 성공 횟수 : 620회
# test 횟수 : 694, 성공 횟수 : 659
# 94.95677233429394
# 0.21865087436487873
# 현재 진행 상황 : 50 회
# 성공 횟수 : 47회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 150 회
# 성공 횟수 : 147회
# 현재 진행 상황 : 200 회
# 성공 횟수 : 197회
# 현재 진행 상황 : 250 회
# 성공 횟수 : 245회
# 현재 진행 상황 : 250 회
# 성공 횟수 : 245회
# 현재 진행 상황 : 250 회
# 성공 횟수 : 245회
# 현재 진행 상황 : 250 회
# 성공 횟수 : 245회
# 현재 진행 상황 : 250 회
# 성공 횟수 : 245회
# 현재 진행 상황 : 250 회
# 성공 횟수 : 245회
# 현재 진행 상황 : 250 회
# 성공 횟수 : 245회
# 현재 진행 상황 : 250 회
# 성공 횟수 : 245회
# 현재 진행 상황 : 250 회
# 성공 횟수 : 245회
# 현재 진행 상황 : 300 회
# 성공 횟수 : 292회
# 현재 진행 상황 : 350 회
# 성공 횟수 : 342회
# 현재 진행 상황 : 400 회
# 성공 횟수 : 391회
# 현재 진행 상황 : 450 회
# 성공 횟수 : 438회
# 현재 진행 상황 : 450 회
# 성공 횟수 : 438회
# 현재 진행 상황 : 450 회
# 성공 횟수 : 438회
# 현재 진행 상황 : 450 회
# 성공 횟수 : 438회
# 현재 진행 상황 : 450 회
# 성공 횟수 : 438회
# 현재 진행 상황 : 450 회
# 성공 횟수 : 438회
# 현재 진행 상황 : 450 회
# 성공 횟수 : 438회
# 현재 진행 상황 : 450 회
# 성공 횟수 : 438회
# 현재 진행 상황 : 450 회
# 성공 횟수 : 438회
# 현재 진행 상황 : 450 회
# 성공 횟수 : 438회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 486회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 486회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 486회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 486회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 486회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 486회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 486회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 486회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 486회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 486회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 486회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 486회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 486회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 486회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 486회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 486회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 486회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 486회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 486회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 486회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 486회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 486회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 486회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 486회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 486회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 486회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 486회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 486회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 486회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 486회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 486회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 486회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 486회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 486회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 486회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 486회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 486회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 486회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 486회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 486회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 486회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 486회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 486회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 486회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 486회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 486회
# 현재 진행 상황 : 550 회
# 성공 횟수 : 536회
# 현재 진행 상황 : 600 회
# 성공 횟수 : 586회
# 현재 진행 상황 : 650 회
# 성공 횟수 : 635회
# test 횟수 : 694, 성공 횟수 : 678
# 97.69452449567723
# 0.2989002794485139
# 현재 진행 상황 : 50 회
# 성공 횟수 : 47회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 150 회
# 성공 횟수 : 147회
# 현재 진행 상황 : 200 회
# 성공 횟수 : 197회
# 현재 진행 상황 : 250 회
# 성공 횟수 : 247회
# 현재 진행 상황 : 250 회
# 성공 횟수 : 247회
# 현재 진행 상황 : 250 회
# 성공 횟수 : 247회
# 현재 진행 상황 : 250 회
# 성공 횟수 : 247회
# 현재 진행 상황 : 250 회
# 성공 횟수 : 247회
# 현재 진행 상황 : 250 회
# 성공 횟수 : 247회
# 현재 진행 상황 : 250 회
# 성공 횟수 : 247회
# 현재 진행 상황 : 250 회
# 성공 횟수 : 247회
# 현재 진행 상황 : 250 회
# 성공 횟수 : 247회
# 현재 진행 상황 : 300 회
# 성공 횟수 : 296회
# 현재 진행 상황 : 350 회
# 성공 횟수 : 346회
# 현재 진행 상황 : 400 회
# 성공 횟수 : 395회
# 현재 진행 상황 : 450 회
# 성공 횟수 : 445회
# 현재 진행 상황 : 450 회
# 성공 횟수 : 445회
# 현재 진행 상황 : 450 회
# 성공 횟수 : 445회
# 현재 진행 상황 : 450 회
# 성공 횟수 : 445회
# 현재 진행 상황 : 450 회
# 성공 횟수 : 445회
# 현재 진행 상황 : 450 회
# 성공 횟수 : 445회
# 현재 진행 상황 : 450 회
# 성공 횟수 : 445회
# 현재 진행 상황 : 450 회
# 성공 횟수 : 445회
# 현재 진행 상황 : 450 회
# 성공 횟수 : 445회
# 현재 진행 상황 : 450 회
# 성공 횟수 : 445회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 495회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 495회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 495회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 495회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 495회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 495회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 495회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 495회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 495회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 495회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 495회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 495회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 495회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 495회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 495회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 495회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 495회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 495회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 495회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 495회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 495회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 495회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 495회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 495회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 495회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 495회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 495회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 495회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 495회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 495회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 495회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 495회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 495회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 495회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 495회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 495회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 495회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 495회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 495회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 495회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 495회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 495회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 495회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 495회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 495회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 495회
# 현재 진행 상황 : 550 회
# 성공 횟수 : 545회
# 현재 진행 상황 : 600 회
# 성공 횟수 : 595회
# 현재 진행 상황 : 650 회
# 성공 횟수 : 645회
# test 횟수 : 694, 성공 횟수 : 689
# 99.27953890489914
# 0.36209033205452124
# 현재 진행 상황 : 50 회
# 성공 횟수 : 25회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 63회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 63회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 63회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 63회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 63회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 63회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 63회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 63회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 63회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 63회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 63회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 63회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 63회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 63회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 63회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 63회
# ...
# 성공 횟수 : 89회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 89회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 89회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 89회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 89회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 89회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 89회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 89회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 89회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 89회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 89회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 89회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 89회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 89회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 89회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 89회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 89회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 89회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 89회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 89회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 89회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 89회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 89회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 89회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 89회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 89회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 89회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 89회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 89회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 89회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 89회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 89회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 89회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 89회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 89회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 89회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 89회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 89회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 89회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 89회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 89회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 89회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 89회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 89회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 89회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 89회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 89회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 89회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 89회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 89회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 89회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 89회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 89회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 89회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 89회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 89회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 89회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 89회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 89회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 89회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 89회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 89회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 89회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 89회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 89회
# 현재 진행 상황 : 150 회
# 성공 횟수 : 134회
# 현재 진행 상황 : 200 회
# 성공 횟수 : 184회
# 현재 진행 상황 : 250 회
# 성공 횟수 : 232회
# 현재 진행 상황 : 250 회
# 성공 횟수 : 232회
# 현재 진행 상황 : 250 회
# 성공 횟수 : 232회
# 현재 진행 상황 : 250 회
# 성공 횟수 : 232회
# 현재 진행 상황 : 250 회
# 성공 횟수 : 232회
# 현재 진행 상황 : 250 회
# 성공 횟수 : 232회
# 현재 진행 상황 : 250 회
# 성공 횟수 : 232회
# 현재 진행 상황 : 250 회
# 성공 횟수 : 232회
# 현재 진행 상황 : 250 회
# 성공 횟수 : 232회
# 현재 진행 상황 : 300 회
# 성공 횟수 : 278회
# 현재 진행 상황 : 350 회
# 성공 횟수 : 328회
# 현재 진행 상황 : 400 회
# 성공 횟수 : 378회
# 현재 진행 상황 : 450 회
# 성공 횟수 : 423회
# 현재 진행 상황 : 450 회
# 성공 횟수 : 423회
# 현재 진행 상황 : 450 회
# 성공 횟수 : 423회
# 현재 진행 상황 : 450 회
# 성공 횟수 : 423회
# 현재 진행 상황 : 450 회
# 성공 횟수 : 423회
# 현재 진행 상황 : 450 회
# 성공 횟수 : 423회
# 현재 진행 상황 : 450 회
# 성공 횟수 : 423회
# 현재 진행 상황 : 450 회
# 성공 횟수 : 423회
# 현재 진행 상황 : 450 회
# 성공 횟수 : 423회
# 현재 진행 상황 : 450 회
# 성공 횟수 : 423회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 473회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 473회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 473회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 473회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 473회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 473회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 473회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 473회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 473회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 473회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 473회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 473회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 473회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 473회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 473회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 473회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 473회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 473회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 473회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 473회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 473회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 473회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 473회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 473회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 473회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 473회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 473회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 473회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 473회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 473회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 473회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 473회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 473회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 473회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 473회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 473회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 473회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 473회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 473회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 473회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 473회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 473회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 473회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 473회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 473회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 473회
# 현재 진행 상황 : 550 회
# 성공 횟수 : 522회
# 현재 진행 상황 : 600 회
# 성공 횟수 : 570회
# 현재 진행 상황 : 650 회
# 성공 횟수 : 613회
# test 횟수 : 694, 성공 횟수 : 648
# 93.37175792507205
# 0.18541942435415804
# 현재 진행 상황 : 50 회
# 성공 횟수 : 47회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 150 회
# 성공 횟수 : 147회
# 현재 진행 상황 : 200 회
# 성공 횟수 : 197회
# 현재 진행 상황 : 250 회
# 성공 횟수 : 247회
# 현재 진행 상황 : 250 회
# 성공 횟수 : 247회
# 현재 진행 상황 : 250 회
# 성공 횟수 : 247회
# 현재 진행 상황 : 250 회
# 성공 횟수 : 247회
# 현재 진행 상황 : 250 회
# 성공 횟수 : 247회
# 현재 진행 상황 : 250 회
# 성공 횟수 : 247회
# 현재 진행 상황 : 250 회
# 성공 횟수 : 247회
# 현재 진행 상황 : 250 회
# 성공 횟수 : 247회
# 현재 진행 상황 : 250 회
# 성공 횟수 : 247회
# 현재 진행 상황 : 300 회
# 성공 횟수 : 294회
# 현재 진행 상황 : 350 회
# 성공 횟수 : 344회
# 현재 진행 상황 : 400 회
# 성공 횟수 : 394회
# 현재 진행 상황 : 450 회
# 성공 횟수 : 443회
# 현재 진행 상황 : 450 회
# 성공 횟수 : 443회
# 현재 진행 상황 : 450 회
# 성공 횟수 : 443회
# 현재 진행 상황 : 450 회
# 성공 횟수 : 443회
# 현재 진행 상황 : 450 회
# 성공 횟수 : 443회
# 현재 진행 상황 : 450 회
# 성공 횟수 : 443회
# 현재 진행 상황 : 450 회
# 성공 횟수 : 443회
# 현재 진행 상황 : 450 회
# 성공 횟수 : 443회
# 현재 진행 상황 : 450 회
# 성공 횟수 : 443회
# 현재 진행 상황 : 450 회
# 성공 횟수 : 443회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 493회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 493회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 493회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 493회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 493회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 493회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 493회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 493회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 493회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 493회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 493회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 493회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 493회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 493회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 493회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 493회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 493회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 493회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 493회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 493회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 493회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 493회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 493회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 493회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 493회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 493회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 493회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 493회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 493회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 493회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 493회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 493회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 493회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 493회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 493회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 493회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 493회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 493회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 493회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 493회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 493회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 493회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 493회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 493회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 493회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 493회
# 현재 진행 상황 : 550 회
# 성공 횟수 : 543회
# 현재 진행 상황 : 600 회
# 성공 횟수 : 593회
# 현재 진행 상황 : 650 회
# 성공 횟수 : 643회
# test 횟수 : 694, 성공 횟수 : 686
# 98.84726224783861
# 0.2633295851119257
# 현재 진행 상황 : 50 회
# 성공 횟수 : 47회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 150 회
# 성공 횟수 : 147회
# 현재 진행 상황 : 200 회
# 성공 횟수 : 197회
# 현재 진행 상황 : 250 회
# 성공 횟수 : 247회
# 현재 진행 상황 : 250 회
# 성공 횟수 : 247회
# 현재 진행 상황 : 250 회
# 성공 횟수 : 247회
# 현재 진행 상황 : 250 회
# 성공 횟수 : 247회
# 현재 진행 상황 : 250 회
# 성공 횟수 : 247회
# 현재 진행 상황 : 250 회
# 성공 횟수 : 247회
# 현재 진행 상황 : 250 회
# 성공 횟수 : 247회
# 현재 진행 상황 : 250 회
# 성공 횟수 : 247회
# 현재 진행 상황 : 250 회
# 성공 횟수 : 247회
# 현재 진행 상황 : 300 회
# 성공 횟수 : 297회
# 현재 진행 상황 : 350 회
# 성공 횟수 : 347회
# 현재 진행 상황 : 400 회
# 성공 횟수 : 397회
# 현재 진행 상황 : 450 회
# 성공 횟수 : 447회
# 현재 진행 상황 : 450 회
# 성공 횟수 : 447회
# 현재 진행 상황 : 450 회
# 성공 횟수 : 447회
# 현재 진행 상황 : 450 회
# 성공 횟수 : 447회
# 현재 진행 상황 : 450 회
# 성공 횟수 : 447회
# 현재 진행 상황 : 450 회
# 성공 횟수 : 447회
# 현재 진행 상황 : 450 회
# 성공 횟수 : 447회
# 현재 진행 상황 : 450 회
# 성공 횟수 : 447회
# 현재 진행 상황 : 450 회
# 성공 횟수 : 447회
# 현재 진행 상황 : 450 회
# 성공 횟수 : 447회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 497회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 497회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 497회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 497회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 497회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 497회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 497회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 497회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 497회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 497회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 497회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 497회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 497회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 497회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 497회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 497회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 497회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 497회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 497회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 497회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 497회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 497회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 497회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 497회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 497회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 497회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 497회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 497회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 497회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 497회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 497회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 497회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 497회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 497회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 497회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 497회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 497회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 497회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 497회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 497회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 497회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 497회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 497회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 497회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 497회
# 현재 진행 상황 : 500 회
# 성공 횟수 : 497회
# 현재 진행 상황 : 550 회
# 성공 횟수 : 547회
# 현재 진행 상황 : 600 회
# 성공 횟수 : 597회
# 현재 진행 상황 : 650 회
# 성공 횟수 : 647회
# test 횟수 : 694, 성공 횟수 : 691
# 99.56772334293949
# 0.33777687139797563

# %%
for i in range(len(tot_acc_list)):
    print(thres_list[i])
    print(tot_acc_list[i])
    print(tot_list_area[i])
    plt.figure(figsize = (8, 4))
    plt.plot(range_val,tot_acc_list[i])
    plt.plot(range_val,tot_list_area[i])
    plt.scatter(range_val, tot_acc_list[i])
    plt.scatter(range_val, tot_list_area[i])
    plt.show()
# Out:
# -75
# [0.909433962264151, 1.0, 1.0, 1.0]
# [0.22614747695816595, 0.29236994741008443, 0.36355951520374896, 0.4229663731119881]
# -78
# [0.9056603773584906, 0.9886792452830189, 1.0, 1.0]
# [0.22877262109296667, 0.3058167345644057, 0.3733432213186983, 0.4346710371780137]
# -81
# [0.9433962264150944, 1.0, 1.0, 1.0]
# [0.20619939622886935, 0.31352036446743187, 0.40892033446396825, 0.5135098315541743]
# -84
# [0.9735849056603774, 0.9924528301886792, 1.0, 1.0]
# [0.22600692908733153, 0.3534993396543056, 0.4646943803635409, 0.5944617533046505]
# -87
# [0.909433962264151, 0.9660377358490566, 1.0, 1.0]
# [0.2189160946046487, 0.394120717642149, 0.5585643577873151, 0.7115871760656214]
# -90
# [0.9547169811320755, 1.0, 1.0, 1.0]
# [0.29558465930928296, 0.5148726882684105, 0.6884274472993865, 0.835744821667041]

# %%
train_dir = './walkdata/train/'
test_dir = './walkdata/test/'

ref_mag_dir = '../magx.txt'

thres_list = [-57, -60, -63, -66, -69, -72]
range_val = [2, 4, 6 ,8]
range_val2 = [1, 1, 2, 2, 3]
area_thres1 = 0.0
area_thres2 = 1.0

model = wifimodel(train_dir, test_dir, ref_mag_dir)

# %%
tot_acc_list = []
tot_list_area = []

tot_area_dist = []
for thres in thres_list:
    model.create_refwifi(thres)
    acc_list = []
    list_area = []
    area_dist = []
    for rang in range_val:
        model.define_range(rang, rang)
        cord, acc, ara, fail = model.test_all()
        acc_list.append(acc)
        list_area.append(ara)
        area_dist.append(model.area_list)
    tot_acc_list.append(acc_list)
    tot_list_area.append(list_area)
    tot_area_dist.append(area_dist)
# Out:
# 현재 진행 상황 : 100 회
# 성공 횟수 : 94회
# 현재 진행 상황 : 200 회
# 성공 횟수 : 189회
# test 횟수 : 265, 성공 횟수 : 241
# 90.94339622641509
# 0.1663566071001321
# 현재 진행 상황 : 100 회
# 성공 횟수 : 100회
# 현재 진행 상황 : 200 회
# 성공 횟수 : 200회
# test 횟수 : 265, 성공 횟수 : 256
# 96.60377358490567
# 0.2675355813058583
# 현재 진행 상황 : 100 회
# 성공 횟수 : 100회
# 현재 진행 상황 : 200 회
# 성공 횟수 : 200회
# test 횟수 : 265, 성공 횟수 : 264
# 99.62264150943396
# 0.389445682523994
# 현재 진행 상황 : 100 회
# 성공 횟수 : 100회
# 현재 진행 상황 : 200 회
# 성공 횟수 : 200회
# test 횟수 : 265, 성공 횟수 : 265
# 100.0
# 0.5506861477158251
# 현재 진행 상황 : 100 회
# 성공 횟수 : 91회
# 현재 진행 상황 : 200 회
# 성공 횟수 : 184회
# test 횟수 : 265, 성공 횟수 : 241
# 90.94339622641509
# 0.140581246599804
# 현재 진행 상황 : 100 회
# 성공 횟수 : 97회
# 현재 진행 상황 : 200 회
# 성공 횟수 : 197회
# test 횟수 : 265, 성공 횟수 : 262
# 98.86792452830188
# 0.1782252246620321
# 현재 진행 상황 : 100 회
# 성공 횟수 : 100회
# 현재 진행 상황 : 200 회
# 성공 횟수 : 200회
# test 횟수 : 265, 성공 횟수 : 265
# 100.0
# 0.2970769938574709
# 현재 진행 상황 : 100 회
# 성공 횟수 : 100회
# 현재 진행 상황 : 200 회
# 성공 횟수 : 200회
# test 횟수 : 265, 성공 횟수 : 265
# 100.0
# 0.35476021720707834
# 현재 진행 상황 : 100 회
# 성공 횟수 : 87회
# 현재 진행 상황 : 200 회
# 성공 횟수 : 171회
# test 횟수 : 265, 성공 횟수 : 235
# 88.67924528301887
# 0.13948033338757027
# 현재 진행 상황 : 100 회
# 성공 횟수 : 100회
# 현재 진행 상황 : 200 회
# 성공 횟수 : 200회
# test 횟수 : 265, 성공 횟수 : 265
# 100.0
# 0.18763245777554488
# 현재 진행 상황 : 100 회
# 성공 횟수 : 100회
# 현재 진행 상황 : 200 회
# 성공 횟수 : 200회
# test 횟수 : 265, 성공 횟수 : 265
# 100.0
# 0.23792783440951418
# 현재 진행 상황 : 100 회
# 성공 횟수 : 100회
# 현재 진행 상황 : 200 회
# 성공 횟수 : 200회
# test 횟수 : 265, 성공 횟수 : 265
# 100.0
# 0.29887204770366643
# 현재 진행 상황 : 100 회
# 성공 횟수 : 91회
# 현재 진행 상황 : 200 회
# 성공 횟수 : 186회
# test 횟수 : 265, 성공 횟수 : 251
# 94.71698113207547
# 0.1917773901062543
# 현재 진행 상황 : 100 회
# 성공 횟수 : 100회
# 현재 진행 상황 : 200 회
# 성공 횟수 : 200회
# test 횟수 : 265, 성공 횟수 : 265
# 100.0
# 0.21130022064919357
# 현재 진행 상황 : 100 회
# 성공 횟수 : 100회
# 현재 진행 상황 : 200 회
# 성공 횟수 : 200회
# test 횟수 : 265, 성공 횟수 : 265
# 100.0
# 0.24446159479964502
# 현재 진행 상황 : 100 회
# 성공 횟수 : 100회
# 현재 진행 상황 : 200 회
# 성공 횟수 : 200회
# test 횟수 : 265, 성공 횟수 : 265
# 100.0
# 0.30039835886985317
# 현재 진행 상황 : 100 회
# 성공 횟수 : 98회
# 현재 진행 상황 : 200 회
# 성공 횟수 : 198회
# test 횟수 : 265, 성공 횟수 : 261
# 98.49056603773585
# 0.1830548247585411
# 현재 진행 상황 : 100 회
# 성공 횟수 : 100회
# 현재 진행 상황 : 200 회
# 성공 횟수 : 200회
# test 횟수 : 265, 성공 횟수 : 265
# 100.0
# 0.23213330045973607
# 현재 진행 상황 : 100 회
# 성공 횟수 : 100회
# 현재 진행 상황 : 200 회
# 성공 횟수 : 200회
# test 횟수 : 265, 성공 횟수 : 265
# 100.0
# 0.2847361827352053
# 현재 진행 상황 : 100 회
# 성공 횟수 : 100회
# 현재 진행 상황 : 200 회
# 성공 횟수 : 200회
# test 횟수 : 265, 성공 횟수 : 265
# 100.0
# 0.33522299251109866
# 현재 진행 상황 : 100 회
# 성공 횟수 : 93회
# 현재 진행 상황 : 200 회
# 성공 횟수 : 187회
# test 횟수 : 265, 성공 횟수 : 243
# 91.69811320754717
# 0.21464768274374413
# 현재 진행 상황 : 100 회
# 성공 횟수 : 96회
# 현재 진행 상황 : 200 회
# 성공 횟수 : 196회
# test 횟수 : 265, 성공 횟수 : 261
# 98.49056603773585
# 0.27609007638809324
# 현재 진행 상황 : 100 회
# 성공 횟수 : 100회
# 현재 진행 상황 : 200 회
# 성공 횟수 : 200회
# test 횟수 : 265, 성공 횟수 : 265
# 100.0
# 0.31939736192450024
# 현재 진행 상황 : 100 회
# 성공 횟수 : 100회
# 현재 진행 상황 : 200 회
# 성공 횟수 : 200회
# test 횟수 : 265, 성공 횟수 : 265
# 100.0
# 0.391670735813981

# %%
for i in range(len(tot_acc_list)):
    print(thres_list[i])
    print(tot_acc_list[i])
    print(tot_list_area[i])
    plt.figure(figsize = (8, 4))
    plt.plot(range_val,tot_acc_list[i])
    plt.plot(range_val,tot_list_area[i])
    plt.scatter(range_val, tot_acc_list[i])
    plt.scatter(range_val, tot_list_area[i])
    plt.show()
# Out:
# -57
# [0.909433962264151, 0.9660377358490566, 0.9962264150943396, 1.0]
# [0.1663566071001321, 0.2675355813058583, 0.389445682523994, 0.5506861477158251]
# -60
# [0.909433962264151, 0.9886792452830189, 1.0, 1.0]
# [0.140581246599804, 0.1782252246620321, 0.2970769938574709, 0.35476021720707834]
# -63
# [0.8867924528301887, 1.0, 1.0, 1.0]
# [0.13948033338757027, 0.18763245777554488, 0.23792783440951418, 0.29887204770366643]
# -66
# [0.9471698113207547, 1.0, 1.0, 1.0]
# [0.1917773901062543, 0.21130022064919357, 0.24446159479964502, 0.30039835886985317]
# -69
# [0.9849056603773585, 1.0, 1.0, 1.0]
# [0.1830548247585411, 0.23213330045973607, 0.2847361827352053, 0.33522299251109866]
# -72
# [0.9169811320754717, 0.9849056603773585, 1.0, 1.0]
# [0.21464768274374413, 0.27609007638809324, 0.31939736192450024, 0.391670735813981]
